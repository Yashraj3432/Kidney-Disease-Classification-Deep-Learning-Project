# %%
! pip install mlflow
# Out:
# Collecting mlflow
#   Using cached mlflow-2.11.3-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: click<9,>=7.0 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from mlflow) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from mlflow) (3.0.0)
# Requirement already satisfied: entrypoints<1 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from mlflow) (0.4)
# Collecting gitpython<4,>=3.1.9 (from mlflow)
#   Using cached GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from mlflow) (6.0.1)
# Requirement already satisfied: protobuf<5,>=3.12.0 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from mlflow) (4.25.3)
# Requirement already satisfied: pytz<2025 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from mlflow) (2024.1)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from mlflow) (2.31.0)
# Requirement already satisfied: packaging<24 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from mlflow) (23.2)
# Collecting importlib-metadata!=4.7.0,<8,>=3.7.0 (from mlflow)
#   Using cached importlib_metadata-7.1.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from mlflow) (0.4.4)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Using cached alembic-1.13.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Using cached docker-7.0.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting Flask<4 (from mlflow)
#   Using cached flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy<2 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from mlflow) (1.26.4)
# Requirement already satisfied: scipy<2 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from mlflow) (1.13.0)
# Requirement already satisfied: pandas<3 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from mlflow) (2.2.1)
# Requirement already satisfied: querystring-parser<2 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from mlflow) (1.2.4)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from mlflow) (2.0.29)
# Collecting scikit-learn<2 (from mlflow)
#   Downloading scikit_learn-1.4.2-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: pyarrow<16,>=4.0.0 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from mlflow) (15.0.2)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from mlflow) (3.6)
# Collecting matplotlib<4 (from mlflow)
#   Using cached matplotlib-3.8.4-cp311-cp311-win_amd64.whl.metadata (5.9 kB)
# Collecting graphene<4 (from mlflow)
#   Using cached graphene-3.3-py2.py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: waitress<4 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from mlflow) (3.0.0)
# Collecting Jinja2<4,>=3.0 (from mlflow)
#   Using cached Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow)
#   Downloading Mako-1.3.3-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (4.11.0)
# Requirement already satisfied: colorama in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from click<9,>=7.0->mlflow) (0.4.6)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from docker<8,>=4.0.0->mlflow) (2.2.1)
# Requirement already satisfied: pywin32>=304 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from docker<8,>=4.0.0->mlflow) (306)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from Flask<4->mlflow) (3.0.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from Flask<4->mlflow) (2.1.2)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from Flask<4->mlflow) (1.7.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=3.1.9->mlflow)
#   Using cached gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from graphene<4->mlflow) (3.2.3)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Using cached graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: aniso8601<10,>=8 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from graphene<4->mlflow) (9.0.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow) (3.18.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from Jinja2<4,>=3.0->mlflow) (2.1.5)
# Collecting contourpy>=1.0.1 (from matplotlib<4->mlflow)
#   Using cached contourpy-1.2.1-cp311-cp311-win_amd64.whl.metadata (5.8 kB)
# Requirement already satisfied: cycler>=0.10 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from matplotlib<4->mlflow) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from matplotlib<4->mlflow) (1.4.5)
# Requirement already satisfied: pillow>=8 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from matplotlib<4->mlflow) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from matplotlib<4->mlflow) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from matplotlib<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from pandas<3->mlflow) (2024.1)
# Requirement already satisfied: six in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from querystring-parser<2->mlflow) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from requests<3,>=2.17.3->mlflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from requests<3,>=2.17.3->mlflow) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from requests<3,>=2.17.3->mlflow) (2024.2.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from scikit-learn<2->mlflow) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from scikit-learn<2->mlflow) (3.4.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.0.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\yashr\desktop\new folder\kidney-disease-classification-deep-learning-project\.venv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow) (5.0.1)
# Using cached mlflow-2.11.3-py3-none-any.whl (19.7 MB)
# Using cached alembic-1.13.1-py3-none-any.whl (233 kB)
# Using cached docker-7.0.0-py3-none-any.whl (147 kB)
# Using cached flask-3.0.3-py3-none-any.whl (101 kB)
# Using cached GitPython-3.1.43-py3-none-any.whl (207 kB)
# Using cached graphene-3.3-py2.py3-none-any.whl (128 kB)
# Using cached importlib_metadata-7.1.0-py3-none-any.whl (24 kB)
# Using cached Jinja2-3.1.3-py3-none-any.whl (133 kB)
# Using cached matplotlib-3.8.4-cp311-cp311-win_amd64.whl (7.7 MB)
# Downloading scikit_learn-1.4.2-cp311-cp311-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB 640.0 kB/s eta 0:00:17
#    - -------------------------------------- 0.4/10.6 MB 3.3 MB/s eta 0:00:04
#    --- ------------------------------------ 1.0/10.6 MB 6.0 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.4/10.6 MB 6.7 MB/s eta 0:00:02
#    ------ --------------------------------- 1.8/10.6 MB 7.2 MB/s eta 0:00:02
#    -------- ------------------------------- 2.3/10.6 MB 7.6 MB/s eta 0:00:02
#    --------- ------------------------------ 2.6/10.6 MB 8.0 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.1/10.6 MB 8.3 MB/s eta 0:00:01
#    ------------- -------------------------- 3.6/10.6 MB 8.2 MB/s eta 0:00:01
#    ------------- -------------------------- 3.6/10.6 MB 8.0 MB/s eta 0:00:01
#    -------------- ------------------------- 3.8/10.6 MB 7.1 MB/s eta 0:00:01
#    --------------- ------------------------ 4.2/10.6 MB 7.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.5/10.6 MB 7.2 MB/s eta 0:00:01
#    ------------------ --------------------- 4.9/10.6 MB 7.3 MB/s eta 0:00:01
#    -------------------- ------------------- 5.4/10.6 MB 7.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.8/10.6 MB 7.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.2/10.6 MB 7.6 MB/s eta 0:00:01
#    ------------------------ --------------- 6.6/10.6 MB 7.6 MB/s eta 0:00:01
#    -------------------------- ------------- 7.0/10.6 MB 7.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.5/10.6 MB 8.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.9/10.6 MB 8.1 MB/s eta 0:00:01
#    ------------------------------- -------- 8.5/10.6 MB 8.2 MB/s eta 0:00:01
#    --------------------------------- ------ 8.9/10.6 MB 8.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.5/10.6 MB 8.4 MB/s eta 0:00:01
#    ------------------------------------- -- 10.0/10.6 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------  10.4/10.6 MB 9.0 MB/s eta 0:00:01
#    ---------------------------------------  10.6/10.6 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 8.7 MB/s eta 0:00:00
# Using cached contourpy-1.2.1-cp311-cp311-win_amd64.whl (188 kB)
# Using cached gitdb-4.0.11-py3-none-any.whl (62 kB)
# Using cached graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading Mako-1.3.3-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.8 kB ? eta -:--:--
#    ---------------------------------------- 78.8/78.8 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: Mako, Jinja2, importlib-metadata, graphql-relay, gitdb, contourpy, scikit-learn, matplotlib, graphene, gitpython, Flask, docker, alembic, mlflow
# Successfully installed Flask-3.0.3 Jinja2-3.1.3 Mako-1.3.3 alembic-1.13.1 contourpy-1.2.1 docker-7.0.0 gitdb-4.0.11 gitpython-3.1.43 graphene-3.3 graphql-relay-3.2.0 importlib-metadata-7.1.0 matplotlib-3.8.4 mlflow-2.11.3 scikit-learn-1.4.2

# %%
if tracking_url_type_store != "file":
                signature = mlflow.tensorflow.get_signature(self.model)
                mlflow.keras.log_model(self.model, "model", signature=signature, registered_model_name="VGG16Model")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from mlflow.pyfunc import PyFuncModel
#
# File c:\Users\yashr\Desktop\New folder\Kidney-Disease-Classification-Deep-Learning-Project\.venv\Lib\site-packages\mlflow\__init__.py:34
#      31 from mlflow.version import VERSION
#      33 __version__ = VERSION
# ---> 34 from mlflow import (
#      35     artifacts,  # noqa: F401
#      36     client,  # noqa: F401
#      37     config,  # noqa: F401
#      38     data,  # noqa: F401
#      39     exceptions,  # noqa: F401
#      40     models,  # noqa: F401
#      41     projects,  # noqa: F401
#      42     tracking,  # noqa: F401
#      43 )
#      44 from mlflow.environment_variables import MLFLOW_CONFIGURE_LOGGING
#      45 from mlflow.utils.lazy_load import LazyLoader
#
# File c:\Users\yashr\Desktop\New folder\Kidney-Disease-Classification-Deep-Learning-Project\.venv\Lib\site-packages\mlflow\models\__init__.py:43
#      33 from mlflow.models.evaluation import (
#      34     EvaluationArtifact,
#      35     EvaluationMetric,
#    (...)
#      40     make_metric,
#      41 )
#      42 from mlflow.models.flavor_backend import FlavorBackend
# ---> 43 from mlflow.models.model import Model, get_model_info
#      44 from mlflow.models.python_api import build_docker
#      45 from mlflow.utils.environment import infer_pip_requirements
#
# File c:\Users\yashr\Desktop\New folder\Kidney-Disease-Classification-Deep-Learning-Project\.venv\Lib\site-packages\mlflow\models\model.py:26
#      24 from mlflow.utils.databricks_utils import get_databricks_runtime
#      25 from mlflow.utils.docstring_utils import LOG_MODEL_PARAM_DOCS, format_docstring
# ---> 26 from mlflow.utils.environment import (
#      27     _CONDA_ENV_FILE_NAME,
#      28     _PYTHON_ENV_FILE_NAME,
#      29     _REQUIREMENTS_FILE_NAME,
#      30     _add_or_overwrite_requirements,
#      31     _get_requirements_from_file,
#      32     _remove_requirements,
#      33     _write_requirements_to_file,
#      34 )
#      35 from mlflow.utils.file_utils import TempDir
#      36 from mlflow.utils.uri import (
#      37     append_to_uri_path,
#      38     get_uri_scheme,
#      39 )
#
# File c:\Users\yashr\Desktop\New folder\Kidney-Disease-Classification-Deep-Learning-Project\.venv\Lib\site-packages\mlflow\utils\environment.py:19
#      17 from mlflow.utils import PYTHON_VERSION, insecure_hash
#      18 from mlflow.utils.process import _exec_cmd
# ---> 19 from mlflow.utils.requirements_utils import (
#      20     _infer_requirements,
#      21     _parse_requirements,
#      22     warn_dependency_requirement_mismatches,
#      23 )
#      24 from mlflow.utils.timeout import MlflowTimeoutError, run_with_timeout
#      25 from mlflow.version import VERSION
#
# File c:\Users\yashr\Desktop\New folder\Kidney-Disease-Classification-Deep-Learning-Project\.venv\Lib\site-packages\mlflow\utils\requirements_utils.py:20
#      17 from typing import List, NamedTuple, Optional
#      19 import importlib_metadata
# ---> 20 import pkg_resources  # noqa: TID251
#      21 from packaging.requirements import Requirement
#      22 from packaging.version import InvalidVersion, Version
#
# ModuleNotFoundError: No module named 'pkg_resources'
